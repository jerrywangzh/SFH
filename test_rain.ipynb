# %%
base = "/mnt/e/collegeitem/third1/digitalsignal/practice/finalexp/SFHformer"

# %%
# %cd /mnt/e/collegeitem/third1/digitalsignal/practice/finalexp/SFHformer

# !python test_for_rain100L.py \
  --model SFHformer_l \
  --checkpoint /mnt/e/collegeitem/third1/digitalsignal/practice/finalexp/SFHformer/derain/SFHformer_lrain_rain100L_sfhformer_m_best.pth \
  --data_dir /mnt/e/collegeitem/third1/digitalsignal/practice/finalexp/SFHformer/data/Rain100/rain_data_test_Light \
  --save_dir /mnt/e/collegeitem/third1/digitalsignal/practice/finalexp/SFHformer/logs/fake \
  --num_workers 2
# Out:
# /mnt/e/collegeitem/third1/digitalsignal/practice/finalexp/SFHformer
# ...

# %%
# %cd /mnt/e/collegeitem/third1/digitalsignal/practice/finalexp/SFHformer

# !python test_for_rain100L.py \
  --model SFHformer_l \
  --checkpoint /mnt/e/collegeitem/third1/digitalsignal/practice/finalexp/SFHformer/derain/SFHformer_lrain_rain100L_sfhformer_m_best.pth \
  --data_dir /mnt/e/collegeitem/third1/digitalsignal/practice/finalexp/SFHformer/datareal/real_test \
  --save_dir /mnt/e/collegeitem/third1/digitalsignal/practice/finalexp/SFHformer/logs/real \
  --num_workers 2
# Out:
# /mnt/e/collegeitem/third1/digitalsignal/practice/finalexp/SFHformer
# ...

# %%
# %cd /mnt/e/collegeitem/third1/digitalsignal/practice/finalexp/SFHformer

# !python test_for_rain100L.py \
  --model SFHformer_l \
  --checkpoint /mnt/e/collegeitem/third1/digitalsignal/practice/finalexp/SFHformer/derain/sfhformer_finetune_epoch100_psnr39.89.pth \
  --data_dir /mnt/e/collegeitem/third1/digitalsignal/practice/finalexp/SFHformer/data/Rain100/rain_data_test_Light \
  --save_dir /mnt/e/collegeitem/third1/digitalsignal/practice/finalexp/SFHformer/logs/newmodel_fake \
  --num_workers 2
# Out:
# /mnt/e/collegeitem/third1/digitalsignal/practice/finalexp/SFHformer
# ...

# %%
# %cd /mnt/e/collegeitem/third1/digitalsignal/practice/finalexp/SFHformer

# !python test_for_rain100L.py \
  --model SFHformer_l \
  --checkpoint /mnt/e/collegeitem/third1/digitalsignal/practice/finalexp/SFHformer/derain/sfhformer_finetune_epoch100_psnr39.89.pth \
  --data_dir /mnt/e/collegeitem/third1/digitalsignal/practice/finalexp/SFHformer/datareal/real_test \
  --save_dir /mnt/e/collegeitem/third1/digitalsignal/practice/finalexp/SFHformer/logs/newmodel_real \
  --num_workers 2
# Out:
# /mnt/e/collegeitem/third1/digitalsignal/practice/finalexp/SFHformer
# ...
